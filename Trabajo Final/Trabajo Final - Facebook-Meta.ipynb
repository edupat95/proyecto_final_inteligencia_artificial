# %% [markdown]
# # Grupo 3
# # Alumnos: Eduardo Patinella y Alberto Barrio.

# %% [markdown]
# 1) Búsqueda de tweets con #Facebook y #Meta LIST
# 2) Filtrado y limpiado (eliminar emoticons, hastag, urls) LISTO
# 3) Utilizar etiquetado POS y lematizacion. Hacer nube de palabras con los adjetivos.
# 4) Hacer gráfico de torta con las personas mas mencionadas
# 5) Hacer análisis de sentimiento con Polaridad con respecto al Metaverso#

# %%
import os
from dotenv import load_dotenv
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")

# %%
#Especificamos datos de la consulta
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"v2FullArchiveSearchPython"
}
hastag='(#Facebook) (#Meta OR #Metaverse)'
palabras_spam = '-sanshutoken -btc -buy -blockchain -sale -Clicking -crypto -Offer -bitcoin -#btc -#buy -#blockchain -#sale -#Clicking -#crypto -#Offer -#bitcoin'
params = {
    'query': f'{hastag} -is:retweet {palabras_spam} lang:en', #Va a traer los que tienen el hashtag '#machinelearning' y el -is:retweet es para que no traigra retweets
    'start_time':'2021-10-28T00:00:00.000Z',
    'end_time':'2021-10-29T23:59:00.000Z',
    #'next_token': token,
    'max_results':100  #Y que traiga 100 resultados maximo

}

# %%
#Hacemos la consulta
import requests
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
import pandas as pd
df = pd.json_normalize(response.json()['data'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f8cf9f822e78> in <module>
#       1 #Hacemos la consulta
#       2 import requests
# ----> 3 response = requests.get(url, headers=headers, params=params)
#       4 print(response)
#       5 # Generar excepción si la respuesta no es exitosa
#
# NameError: name 'url' is not defined

# %%
from nltk.tokenize import TweetTokenizer # libreria especifica para los tokenizar tweets 

tt = TweetTokenizer() # intanciamos ya que es un modelo lo que vamos a llamar
# Aplicar Tokenizer a la columna
tokenized_text = df['text'].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df
#df.to_csv('con#')
# Out:
#                      id                                               text  \
# 0   1454236343534592000  @elonmusk @nichegamer "𝐌𝐄𝐓𝐀" @facebookapp , 𝐓𝐡...
# 1   1454235492468379650  With Facebook new name (Meta), FAANG will be M...
# 2   1454235433538183168  Rebranding from #Facebook to #Meta is not an a...
# 3   1454235338029899779  Dad Joke OTD:\n\nI told my son Facebook is cha...
# 4   1454235103186628610  @MissionToZyxx Nermit Bundaloy‘s love for virt...
# ..                  ...                                                ...
# 95  1454213825113251848  $WIMI breakout 🏃💨\n\nThe "WiMi Metaverse" trad...
# 96  1454213750005895169  @stevewoz claims @Apple didn’t have to change ...
# 97  1454213702471897089  @Snowden focus on purpose and goal, not name #...
# 98  1454213647031537665  FB goes Meta—Parler app the new Facebook? http...
# 99  1454213404445581313  I wonder what a “peaceful demonstration” will ...
#
#                                        tokenized_text
# 0   [@elonmusk, @nichegamer, ", 𝐌𝐄𝐓𝐀, ", @facebook...
# 1   [With, Facebook, new, name, (, Meta, ), ,, FAA...
# 2   [Rebranding, from, #Facebook, to, #Meta, is, n...
# 3   [Dad, Joke, OTD, :, I, told, my, son, Facebook...
# 4   [@MissionToZyxx, Nermit, Bundaloy, ‘, s, love,...
# ..                                                ...
# 95  [$, WIMI, breakout, 🏃, 💨, The, ", WiMi, Metave...
# 96  [@stevewoz, claims, @Apple, didn, ’, t, have, ...
# 97  [@Snowden, focus, on, purpose, and, goal, ,, n...
# 98  [FB, goes, Meta, —, Parler, app, the, new, Fac...
# 99  [I, wonder, what, a, “, peaceful, demonstratio...
#
# [100 rows x 3 columns]

# %%
# Crear lista sin stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import re
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean(x):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F" # emoticons
        u"\U0001F300-\U0001F5FF" # symbols & pictographs
        u"\U0001F680-\U0001F6FF" # transport & map symbols
        u"\U0001F1E0-\U0001F1FF" # flags (iOS)
                           "]+", flags = re.UNICODE)
    n = regrex_pattern.sub(r'', x)
    if (not x.lower() in stop_words) and (n != ''):
        return True
    else:
        return False
for index, tweet in enumerate(tokenized_text):
    tweet = [x for x in tweet if clean(x)]
    tokenized_text[index] = tweet

df["tokenized_text"] = tokenized_text
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eduardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-482c0d3c7ed6> in <module>
#      19     else:
#      20         return False
# ---> 21 for index, tweet in enumerate(tokenized_text):
#      22     tweet = [x for x in tweet if clean(x)]
#      23     tokenized_text[index] = tweet
#
# NameError: name 'tokenized_text' is not defined

# %%
#Segunda limpieza para sacar urls, # y palabras de 1 caracter
i=0
list_aux=[]

for text in df['tokenized_text']:
    #text=eval(str_text) # lo convertimos en lista para poder iterar por palabra
    #print("\nTEXTO A ANALIZAR ->",text)
    j=0
    for palabra in text:
        #print("->palabra a analizar: ", palabra)
        if(re.search('^#+',palabra)):
            palabra = re.sub(r'.', '', palabra, count = 1) # eliminamos el primer caracter que es "#"
            list_aux.append(palabra)
            j=j+1
        elif(re.search("^http+",palabra)):
            j=j+1#print("->palabra sacar ->", palabra)
        elif(len(palabra)==1):
            j=j+1
            #print("->palabra sacada ->", palabra)
        else:
            list_aux.append(palabra)
            j=j+1
    
    print(len(df['tokenized_text'][i]), "<->",)
    #df['tokenized_text'][i]=list_aux
    list_aux=[]
    i=i+1
     
df=df[['tokenized_text']]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     971         try:
# --> 972             self._set_with_engine(key, value)
#     973         except (KeyError, ValueError):
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1006         validate_numeric_casting(self.dtype, value)
# -> 1007         self._values[loc] = value
#    1008
#
# ValueError: NumPy boolean array indexing assignment cannot assign 23 input values to the 11 output values where the mask is true
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-333-34027b23eddc> in <module>
#      22             j=j+1
#      23
# ---> 24     df['tokenized_text'][i]=list_aux
#      25     list_aux=[]
#      26     i=i+1
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     978             else:
#     979                 # GH#12862 adding a new key to the Series
# --> 980                 self.loc[key] = value
#     981
#     982         except TypeError as err:
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
# -> 1637             self._setitem_single_block(indexer, value, name)
#    1638
#    1639     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1859         # actually do the set
#    1860         self.obj._consolidate_inplace()
# -> 1861         self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1862         self.obj._maybe_update_cacher(clear=True)
#    1863
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in setitem(self, indexer, value)
#     566
#     567     def setitem(self, indexer, value) -> "BlockManager":
# --> 568         return self.apply("setitem", indexer=indexer, value=value)
#     569
#     570     def putmask(self, mask, new, align: bool = True, axis: int = 0):
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     997
#     998         # length checking
# --> 999         check_setitem_lengths(indexer, value, values)
#    1000         exact_match = (
#    1001             len(arr_value.shape)
#
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/indexers.py in check_setitem_lengths(indexer, value, values)
#     159                     and len(indexer[indexer]) == len(value)
#     160                 ):
# --> 161                     raise ValueError(
#     162                         "cannot set using a list-like indexer "
#     163                         "with a different length than the value"
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
df
# Out:
#                      id                                               text  \
# 0   1454236343534592000  @elonmusk @nichegamer "𝐌𝐄𝐓𝐀" @facebookapp , 𝐓𝐡...
# 1   1454235492468379650  With Facebook new name (Meta), FAANG will be M...
# 2   1454235433538183168  Rebranding from #Facebook to #Meta is not an a...
# 3   1454235338029899779  Dad Joke OTD:\n\nI told my son Facebook is cha...
# 4   1454235103186628610  @MissionToZyxx Nermit Bundaloy‘s love for virt...
# ..                  ...                                                ...
# 95  1454116778846609416  🚨 Social Media Industry Update 🚨\n\nHave you s...
# 96  1454116766846701571  Well written piece with a bit of personality, ...
# 97  1454116733904568321  Facebook’s new name Meta is Greek for “beyond,...
# 98  1454116628333928453  Ever Meta person whose Face lights up like a b...
# 99  1454116597564682240  The Last Friend ready to join the #Metaverse.\...
#
#                                        tokenized_text
# 0   [@elonmusk, @nichegamer, ", 𝐌𝐄𝐓𝐀, ", @facebook...
# 1   [With, Facebook, new, name, (, Meta, ), ,, FAA...
# 2   [Rebranding, from, #Facebook, to, #Meta, is, n...
# 3   [Dad, Joke, OTD, :, I, told, my, son, Facebook...
# 4   [@MissionToZyxx, Nermit, Bundaloy, ‘, s, love,...
# ..                                                ...
# 95  [🚨, Social, Media, Industry, Update, 🚨, Have, ...
# 96  [Well, written, piece, with, a, bit, of, perso...
# 97  [Facebook, ’, s, new, name, Meta, is, Greek, f...
# 98  [Ever, Meta, person, whose, Face, lights, up, ...
# 99  [The, Last, Friend, ready, to, join, the, #Met...
#
# [1099 rows x 3 columns]

# %%
## HACEMOS UN GRAFICO DE TORTA PAR SABER CUALES FUERON LOS USUARIOS MAS MENCIONADOS
menciones=[]
i=0
for text in df['tokenized_text']:
    #text=eval(str_text) # lo convertimos en lista para poder iterar por palabra
    #print("\nTEXTO A ANALIZAR ->",text)
    j=0
    for palabra in text:
        #print("->palabra a analizar: ", palabra)
        if(re.search('^@+',palabra)):
            #palabra = re.sub(r'.', '', palabra, count = 1) # eliminamos el primer caracter que es "@"
            #palabra=palabra.lower()
            menciones.append(palabra.lower())
        j=j+1
    i=i+1
    #print("\n TEXTO DEVULETO ->", text) 
menciones
# Out:
# ['@elonmusk',
#  '@nichegamer',
#  '@facebookapp',
#  '@elonmusk',
#  '@missiontozyxx',
#  '@citylcs',
#  '@finkd',
#  '@meta',
#  '@bloktopia',
#  '@bsonblast',
#  '@meta',
#  '@pocnetworknews',
#  '@decentraland',
#  '@thewrap',
#  '@parikpatelcfa',
#  '@cz_binance',
#  '@ovrthereality',
#  '@binance',
#  '@meta',
#  '@facebook',
#  '@cwarzel',
#  '@papitrumpo',
#  '@meta',
#  '@meta',
#  '@finkd',
#  '@sherylsandberg',
#  '@amyklobuchar',
#  '@parliament_jo',
#  '@tyler',
#  '@cameron',
#  '@metagascar_',
#  '@metagascar_com',
#  '@metagas',
#  '@fbnewsroom',
#  '@meta',
#  '@facebook',
#  '@meta',
#  '@msense_app',
#  '@finkd',
#  '@koparafallskid',
#  '@stevewoz',
#  '@apple',
#  '@jack',
#  '@snowden',
#  '@auradeluxe',
#  '@',
#  '@meta',
#  '@meta',
#  '@meta',
#  '@keiichiban',
#  '@msblairewhite',
#  '@vftsolutions',
#  '@portabletvapp',
#  '@directv',
#  '@dish',
#  '@plutotv',
#  '@roku',
#  '@amazonfiretv',
#  '@rt_america',
#  '@youtube',
#  '@jcats2013',
#  '@newsmax',
#  '@gillianmckeith',
#  '@breaking24_7',
#  '@uploadvr',
#  '@facebook',
#  '@yousefmunayyer',
#  '@mattgurney',
#  '@rubinaahmedhaq',
#  '@marcaflalo',
#  '@yourtechreport',
#  '@nataliejennings',
#  '@washingtonpost',
#  '@lifeworks',
#  '@ryantumilty',
#  '@nationalpost',
#  '@jengerson',
#  '@the_lineca',
#  '@bilalv87',
#  '@fbnewsroom',
#  '@meta',
#  '@whitehouse',
#  '@gusgus_gdl',
#  '@franc_7',
#  '@meta',
#  '@gamergy',
#  '@twitterlatam',
#  '@flotus',
#  '@bidenfoundation',
#  '@telegram_es',
#  '@_whats_app__',
#  '@meta',
#  '@mit',
#  '@mitcities',
#  '@larson_mit',
#  '@innovate_cities',
#  '@anncavoukian',
#  '@chanzuckerberg',
#  '@keiomediadesign',
#  '@keioglobal',
#  '@matthewwaldman',
#  '@gemmniex',
#  '@uniswap',
#  '@somniumspace',
#  '@',
#  '@theretweetermag',
#  '@etimeslifestyle',
#  '@zazzle',
#  '@facebook',
#  '@meta',
#  '@metaverseinu',
#  '@fnjacobs',
#  '@fvaannie',
#  '@oloyedey4u',
#  '@oloyedey4u',
#  '@akreana_',
#  '@akreana_',
#  '@gailluck9',
#  '@businessinsider',
#  '@staratlas',
#  '@markzuckernet',
#  '@financialtimes',
#  '@facebook',
#  '@washingtonpost',
#  '@nytimes',
#  '@wsjpolitics',
#  '@wsjopinion',
#  '@reuterspolitics',
#  '@reuters',
#  '@business',
#  '@bpolitics',
#  '@bopinion',
#  '@ap',
#  '@bbc',
#  '@cnbc',
#  '@cnn',
#  '@msnbc',
#  '@thehill',
#  '@forbes',
#  '@edwardsegalcom1',
#  '@revenuemarketer',
#  '@wired',
#  '@facebook',
#  '@meta',
#  '@firstmove',
#  '@cnet',
#  '@facebook',
#  '@maxkeiser',
#  '@finkd',
#  '@facebook',
#  '@bheater',
#  '@thedrum',
#  '@marpipe_hq',
#  '@marpipe_hq',
#  '@meta',
#  '@bbcworld',
#  '@nicolelgill',
#  '@accountabletech',
#  '@ethanz',
#  '@umasspolicy',
#  '@umasscs',
#  '@umasscommdept',
#  '@meta',
#  '@realcandaceo',
#  '@jackposobiec',
#  '@donaldjtrumpjr',
#  '@wpeaster',
#  '@banklesshq',
#  '@techypreacher',
#  '@cnn',
#  '@anthonynoto',
#  '@parikpatelcfa',
#  '@cokedupoptions',
#  '@brianferoldi',
#  '@ritholtz',
#  '@awealthofcs',
#  '@thecompoundnews',
#  '@danprimack',
#  '@samro',
#  '@liebermanaustin',
#  '@david_dierking',
#  '@bykatherineross',
#  '@commondreams',
#  '@logoeps',
#  '@meta',
#  '@metahero_io',
#  '@rob_gryn',
#  '@thetechoutlook',
#  '@brandyljensen',
#  '@freecapecodnews',
#  '@newsasset',
#  '@meta',
#  '@jtsportsbiz',
#  '@drfran',
#  '@realhayman',
#  '@extendedvictory',
#  '@tinabaylocq',
#  '@mr_davidmacias',
#  '@lucasgw',
#  '@seangmann',
#  '@donalleniii',
#  '@nicolelazzaro',
#  '@opethestylist',
#  '@jason',
#  '@theallinpod',
#  '@twistartups',
#  '@chamath',
#  '@henrybelcaster',
#  '@smartnonsense',
#  '@justinpfortier',
#  '@heidibraun',
#  '@businessbarista',
#  '@austin_rief',
#  '@ptetlock',
#  '@meta',
#  '@wsj',
#  '@meta',
#  '@screenrant',
#  '@thematrixmovie',
#  '@vm14872497',
#  '@meta',
#  '@torpor24918710',
#  '@spores_network',
#  '@brentmorrissey',
#  '@meta',
#  '@meta',
#  '@morningexp',
#  '@manilachan',
#  '@forbes',
#  '@francis_monyo',
#  '@efua_1122',
#  '@manilachan',
#  '@starz_254',
#  '@efua_1122',
#  '@uamerica333',
#  '@wendyrogersaz',
#  '@monicaonairtalk',
#  '@meta',
#  '@meta',
#  '@efua_1122',
#  '@efua_1122',
#  '@indopac_info',
#  '@vgmenon99',
#  '@indopacom',
#  '@centcom',
#  '@basharatpeer',
#  '@fmanjoo',
#  '@lrb',
#  '@somersetlevel',
#  '@reutersbiz',
#  '@meta',
#  '@safearnbsc',
#  '@earnhubbsc',
#  '@digg',
#  '@dwnews',
#  '@verge',
#  '@meta',
#  '@facebook',
#  '@wsj',
#  '@srf',
#  '@amywestervelt',
#  '@teaching_soc',
#  '@asateaching',
#  '@kate_sunfish',
#  '@smexaminer',
#  '@mate',
#  '@fosstodon',
#  '@meta',
#  '@facebookai',
#  '@facebookapp',
#  '@watcherguru',
#  '@fiftyandfabblog',
#  '@facebook',
#  '@zuckembergitaly',
#  '@jack',
#  '@tuckercarlson',
#  '@twitter',
#  '@oddtodd12',
#  '@mmpadellan',
#  '@jack',
#  '@tuckercarlson',
#  '@twitter',
#  '@johnkrasinski',
#  '@facebook',
#  '@theofficetv',
#  '@malikofori',
#  '@malikofori',
#  '@mattgurney',
#  '@rubinaahmedhaq',
#  '@marcaflalo',
#  '@yourtechreport',
#  '@nataliejennings',
#  '@washingtonpost',
#  '@lifeworks',
#  '@ryantumilty',
#  '@nationalpost',
#  '@jengerson',
#  '@the_lineca',
#  '@bilalv87',
#  '@facebook',
#  '@meta',
#  '@meta',
#  '@nebraltd',
#  '@potus',
#  '@speakerpelosi',
#  '@vp',
#  '@flippa',
#  '@meta',
#  '@bbcworld',
#  '@nodexl',
#  '@facebook',
#  '@bryantconcepci1',
#  '@juan_alcarazs',
#  '@guitartrovasv',
#  '@gepvchess7',
#  '@diariobitcoin',
#  '@vanguardiavirt1',
#  '@publi_ar',
#  '@dasilvanatalia',
#  '@hashtagmarketi7',
#  '@',
#  '@rev_populi',
#  '@aaubry256',
#  '@aaubry256',
#  '@wired',
#  '@reuters',
#  '@meta',
#  '@meta',
#  '@nehakhanna_07',
#  '@dilipthecherian',
#  '@facebookapp',
#  '@advprashantmali',
#  '@viraggupta',
#  '@subtoconnorpls',
#  '@facebook',
#  '@oculus',
#  '@meta',
#  '@coinmarketcap',
#  '@facebookwatch',
#  '@garyvee',
#  '@npr',
#  '@verge',
#  '@cnet',
#  '@wired',
#  '@iphonedo',
#  '@austinnotduncan',
#  '@foroalfa',
#  '@marzuckerberg',
#  '@yanisvaroufakis',
#  '@decentraland',
#  '@meta',
#  '@prweekus',
#  '@bychrisdaniels',
#  '@meta',
#  '@elonmusk',
#  '@meta',
#  '@etfguide',
#  '@etfaction',
#  '@philbak1',
#  '@leadlagreport',
#  '@kylascan',
#  '@matt_levine',
#  '@bullandbaird',
#  '@j_b_horne',
#  '@lamonicabuzz',
#  '@gerberkawasaki',
#  '@gfilche',
#  '@cfromhertz',
#  '@ojrenick',
#  '@deleggeron',
#  '@theregister',
#  '@cryptotony__',
#  '@radixdlt',
#  '@originprotocol',
#  '@meta',
#  '@guardiannews',
#  '@risepdx',
#  '@drprofitcrypto',
#  '@originprotocol',
#  '@facebook',
#  '@facebook',
#  '@ericbalchunas',
#  '@covered_call',
#  '@davenadig',
#  '@toddcfra',
#  '@matt_hougan',
#  '@sonnenshein',
#  '@dan_pantera',
#  '@mstaretfus',
#  '@nategeraci',
#  '@scarletfu',
#  '@joelwebershow',
#  '@jseyff',
#  '@meta',
#  '@uhivesocial',
#  '@facebook',
#  '@facebookapp',
#  '@meta',
#  '@instagram',
#  '@gibiz',
#  '@brendansinclair',
#  '@finkd',
#  '@facebookapp',
#  '@fbnewsroom',
#  '@meta',
#  '@xplnrs',
#  '@prcwrites',
#  '@novaramedia',
#  '@michaeljswalker',
#  '@aaronbastani',
#  '@nft_ascii',
#  '@efua_1122',
#  '@efua_1122',
#  '@dealmeoutcic',
#  '@meta',
#  '@facebook',
#  '@metaverse',
#  '@coindesk',
#  '@davidzmorris',
#  '@meta',
#  '@uhivesocial',
#  '@pcmag',
#  '@saschasegan',
#  '@donie',
#  '@facebook',
#  '@meta',
#  '@coinmarketcap',
#  '@recode',
#  '@alexfilipin',
#  '@evankirstel',
#  '@ap',
#  '@forbestech',
#  '@charliefink',
#  '@telecoms',
#  '@',
#  '@katherined',
#  '@dsearls',
#  '@shawnp0wers',
#  '@pkoutoupis',
#  '@protocollabs',
#  '@tanyachen',
#  '@verge',
#  '@kucoincom',
#  '@thepressunited',
#  '@meta',
#  '@facebookfr',
#  '@facebookapp',
#  '@meta',
#  '@france24_en',
#  '@bbcworld',
#  '@marketingdive',
#  '@sbrbbq',
#  '@ridddyy',
#  '@meta',
#  '@cnn',
#  '@facebook',
#  '@socialmedia2day',
#  '@adhutchinson',
#  '@snowden',
#  '@techcrunch',
#  '@meta',
#  '@oculus',
#  '@markzuckerbeg',
#  '@meta',
#  '@facebook',
#  '@elonmusk',
#  '@thestreet',
#  '@wersm',
#  '@facebook',
#  '@meta',
#  '@uhivesocial',
#  '@mozesyehudaioff',
#  '@wef',
#  '@wef',
#  '@facebook',
#  '@guardian',
#  '@vulcanforged',
#  '@vulcanforged',
#  '@diamondhandzz',
#  '@coinmarketcap',
#  '@fb_engineering',
#  '@meta',
#  '@facebookapp',
#  '@zuck',
#  '@stephyfung',
#  '@danidoesnotxist',
#  '@reginaturbina',
#  '@br_ifw',
#  '@bfc',
#  '@rushcaroline',
#  '@dematerialised',
#  '@m_h_d_v',
#  '@krista_kim',
#  '@brytehall',
#  '@apompliano',
#  '@meta',
#  '@senwarren',
#  '@gate_io',
#  '@khoa06334556',
#  '@nguyend01246638',
#  '@hahuyhong6',
#  '@khoa06334556',
#  '@nguyend01246638',
#  '@hahuyhong6',
#  '@meta',
#  '@speakerpelosi',
#  '@benkissel',
#  '@oculus',
#  '@meta',
#  '@zjm44',
#  '@twitter',
#  '@meta',
#  '@wendys',
#  '@suzseddon',
#  '@thecoastguy',
#  '@meta',
#  '@oculus',
#  '@_sppu',
#  '@parcello_org',
#  '@its',
#  '@ether_cards',
#  '@facebook',
#  '@mikeisaac',
#  '@alisaras',
#  '@nytimes',
#  '@meta',
#  '@wef',
#  '@medcitynews',
#  '@boztank',
#  '@nbcnewsthink',
#  '@jblefevre60',
#  '@chboursin',
#  '@florenthtmy',
#  '@fgraillot',
#  '@andi_staub',
#  '@xbond49',
#  '@kuriharan',
#  '@verge',
#  '@meta',
#  '@wwe',
#  '@facebook',
#  '@meta',
#  '@meta',
#  '@webex',
#  '@adityarajkaul',
#  '@mikeisaac',
#  '@nytimes',
#  '@daretobe_better',
#  '@',
#  '@medabotsworld',
#  '@adamleealter',
#  '@joerogan',
#  '@shawnyingtju',
#  '@facebook',
#  '@binance',
#  '@coinbase',
#  '@moon',
#  '@tnamediaoffice',
#  '@wbulime',
#  '@ugaman01',
#  '@kisekkapatric7',
#  '@facebook',
#  '@meta',
#  '@snowden',
#  '@meta',
#  '@meta',
#  '@raoulgmi',
#  '@bostonglobe',
#  '@globeopinion',
#  '@mgobrazil',
#  '@libbyh',
#  '@umich',
#  '@umichigannews',
#  '@jared_wadley',
#  '@umisr',
#  '@meta',
#  '@royatv',
#  '@gizmodo',
#  '@rulofq',
#  '@cnbctv18news',
#  '@kanishka9996',
#  '@jchatterleycnn',
#  '@brianstelter',
#  '@firstmove',
#  '@webmarketingcom',
#  '@visualbranding',
#  '@zappythepree',
#  '@kanishka9996',
#  '@dlaignite',
#  '@eric_crux',
#  '@lenwood_ross',
#  '@agsocialmedia',
#  '@trsocialselling',
#  '@brandon1ee',
#  '@aldiuk',
#  '@facebook',
#  '@computerworld',
#  '@mattgaetz',
#  '@repmattgaetz',
#  '@fbi',
#  '@appleosophy',
#  '@facebook',
#  '@computerworld',
#  '@yanisvaroufakis',
#  '@meta',
#  '@secondlife',
#  '@secondlife',
#  '@secondlife',
#  '@catturd2',
#  '@newyorker',
#  '@akrit_michael',
#  '@torontostar',
#  '@simransingxh',
#  '@meta',
#  '@facebook',
#  '@meta',
#  '@facebook',
#  '@shawn_farash',
#  '@bmckenz44559503',
#  '@getridwastaken',
#  '@swiftonsecurity',
#  '@markzuckerbeg',
#  '@wallstmemes',
#  '@verge',
#  '@facebook',
#  '@markritson',
#  '@meta',
#  '@chalkward',
#  '@bbc5live',
#  '@felicityhannah',
#  '@meta',
#  '@facebook',
#  '@allthecitizens',
#  '@seriouslydaft',
#  '@nft_ascii',
#  '@meta',
#  '@business',
#  '@uploadvr',
#  '@seventyfourbbq',
#  '@meta',
#  '@markzuckrbergg',
#  '@meta',
#  '@sachinr27',
#  '@gemmniex',
#  '@uniswap',
#  '@somniumspace',
#  '@personafi_app',
#  '@readyplayerone',
#  '@thielschristian',
#  '@facebook',
#  '@facebookapp',
#  '@thecakemnstr',
#  '@projectoasis_',
#  '@daphnehk',
#  '@facebook',
#  '@meta',
#  '@tripontech',
#  '@trtworld',
#  '@shahed',
#  '@madomarketing',
#  '@social_samosa',
#  '@sdissect',
#  '@emmabostian',
#  '@bruvvereccles',
#  '@meta',
#  '@facebookapp',
#  '@themysticle',
#  '@meta',
#  '@newzoohq',
#  '@nanaakua1',
#  '@gbnews',
#  '@reuters',
#  '@meta',
#  '@finkd',
#  '@verminsupreme',
#  '@thedomains',
#  '@axios',
#  '@cryptomoyt',
#  '@originprotocol',
#  '@whizametservices',
#  '@meta',
#  '@facebookapp',
#  '@axieinfinity',
#  '@originprotocol',
#  '@finkd',
#  '@dca_cryptoz',
#  '@originprotocol',
#  '@cryptotony__',
#  '@originprotocol',
#  '@meta',
#  '@',
#  '@venticrypto',
#  '@tokeninari',
#  '@tokeninari',
#  '@youtube',
#  '@jaydee_757',
#  '@originprotocol',
#  '@indicworld',
#  '@meta',
#  '@indicworld',
#  '@tokens',
#  '@cryptogodjohn',
#  '@originprotocol',
#  '@vegetacrypto1',
#  '@originprotocol',
#  '@conquerercrypto',
#  '@originprotocol',
#  '@japantradingltd',
#  '@originprotocol',
#  '@virginmedia',
#  '@meta',
#  '@mmcrypto',
#  '@originprotocol',
#  '@abc',
#  '@facebookindia',
#  '@digitaljprateek',
#  '@meta',
#  '@facebookapp',
#  '@finkd',
#  '@ninafx_',
#  '@originprotocol',
#  '@vicenews',
#  '@youtube',
#  '@ap',
#  '@msnbc',
#  '@drprofitcrypto',
#  '@originprotocol',
#  '@8',
#  '@businessinsider',
#  '@nytmedia',
#  '@kevinroose',
#  '@fazeclan',
#  '@thetrueamerica5',
#  '@9',
#  '@subimal',
#  '@ceomygovindia',
#  '@dahiya_v',
#  '@thedailyshow',
#  '@cbcindigenous',
#  '@mikeelgan',
#  '@computerworld',
#  '@meta',
#  '@donaldjtrumpjr',
#  '@meta',
#  '@meta',
#  '@meta',
#  '@meta',
#  '@facebookapp',
#  '@fbnewsroom',
#  '@krispykreme',
#  '@meta',
#  '@meta',
#  '@finkd',
#  '@cisco',
#  '@meta',
#  '@facebook',
#  '@umontana',
#  '@pardesoteric',
#  '@wired',
#  '@facebook',
#  '@silver_zelda',
#  '@jamesavincent1',
#  '@irishexaminer',
#  '@sxmcanadatalks',
#  '@mattgurney',
#  '@siriusxmcanada',
#  '@rubinaahmedhaq',
#  '@marcaflalo',
#  '@yourtechreport',
#  '@nataliejennings',
#  '@washingtonpost',
#  '@lifeworks',
#  '@ryantumilty',
#  '@nationalpost',
#  '@jengerson',
#  '@the_lineca',
#  '@1337core',
#  '@ideenfitness',
#  '@ixmagazin',
#  '@varundocrypto',
#  '@srinigoes',
#  '@yourstrulyvish',
#  '@ivivekch',
#  '@spiralynk',
#  '@elviric',
#  '@devinthedude07',
#  '@butterhoops',
#  '@talrick5',
#  '@devowillit',
#  '@mini_doodler',
#  '@meta',
#  '@ownerfacebook',
#  '@wazirxcares',
#  '@amanjai59897980',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@coinmarketcap',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@panthonylg',
#  '@nbcbayarea',
#  '@hadifattah',
#  '@universecrypt',
#  '@spacex',
#  '@nasa',
#  '@commercial_crew',
#  '@esa',
#  '@sanshutoken',
#  '@spacex',
#  '@nasa',
#  '@commercial_crew',
#  '@esa',
#  '@sanshutoken',
#  '@universecrypt',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@spacex',
#  '@nasa',
#  '@commercial_crew',
#  '@esa',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@cointelegraph',
#  '@cointelegraphzn',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@chiesigroup',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@wabdoteth',
#  '@yuppiex2',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@reuters',
#  '@meta',
#  '@opensea',
#  '@1goonrich',
#  '@dogelonmars',
#  '@sanshutoken',
#  '@universecrypt',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@meta',
#  '@meta',
#  '@youtube',
#  '@1goonrich',
#  '@dogelonmars',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@watcherguru',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@spacex',
#  '@nasa',
#  '@commercial_crew',
#  '@esa',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@markzuckerbeg',
#  '@spacex',
#  '@nasa',
#  '@commercial_crew',
#  '@esa',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@themooncarl',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@wazirxindia',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@cryptoforsa',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@alotaibi_aso',
#  '@keefkk',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@fajer_free',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@meta',
#  '@facebookapp',
#  '@iis965',
#  '@alotaibi_aso',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@celoorg',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@cointelegraphzn',
#  '@cointelegraph',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@meta',
#  '@sanshutoken',
#  '@meta',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@senwarren',
#  '@metalab',
#  '@altcoingranny',
#  '@tailstoken',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@nischalshetty',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@nas_almutairi',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@verge',
#  '@amazon',
#  '@daas37_youcef',
#  '@nas_almutairi',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@pumpcoinbets',
#  '@lemmingsnft',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@finkd',
#  '@protocol',
#  '@graham949',
#  '@chucktingle',
#  '@socialnws',
#  '@howardstern',
#  '@sternshow',
#  '@meta',
#  '@meta',
#  '@pcworld',
#  '@tnatw',
#  '@amazon',
#  '@meta',
#  '@vmcombs',
#  '@facebook',
#  '@meta',
#  '@facebook',
#  '@meta',
#  '@reematendulkar',
#  '@oculus',
#  '@legendaryenergy',
#  '@facebookfr',
#  '@finkd',
#  '@meta',
#  '@brianstelter',
#  '@firstmove',
#  '@marzuckerberg',
#  '@elsevier_eng',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@alotaibi_aso',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@bitcoinmagazine',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@bitcoinmagazine',
#  '@mcshane_writes',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@bitcoinmagazine',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@autolivinc',
#  '@sanshutoken',
#  '@sanshutoken',
#  '@universecrypt',
#  '@huobiglobal',
#  ...]

# %%
# EL primer analicis que podemos hacer es analizar la frecuencia de palabras.
from nltk.probability import FreqDist 
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 200
# Obtener frecuencia de cada término
fdist = FreqDist(menciones)

usuarios = []#list(fdist.keys()) 
frecuencias = []#list(fdist.values())

for nombre in fdist:
    frecuencia = fdist[nombre]
    
    if(frecuencia>5):
        #print(frecuencia)
        usuarios.append(nombre)
        frecuencias.append(frecuencia)

plt.pie(frecuencias, labels=usuarios, autopct="%0.1f %%")

plt.show()

# %%
frecuencias
# Out:
# [7, 3, 2, 2]

# %%
usuarios
# Out:
# ['@meta', '@finkd', '@elonmusk', '@facebook']
