# %% [markdown]
# # Ejercicio
#
# - Obtener de la API una lista de Tweets que no sean retweet y que contengan el hashtag #GRAMMYs en inglés. COMPLETADO
# - Realizar la tokenización COMPLETADO
# - Realizar un etiquetado POS con la función pos_tag de NLTK COMPLETADO
# - Obtener la lista y frecuencia de los sustantivos en singular y plural#

# %%
import os
from dotenv import load_dotenv
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")

# %%
url = "https://api.twitter.com/2/tweets/search/recent"
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"v2FullArchiveSearchPython"
}
hastag='#GRAMMYs'
params = {
    'query': f'{hastag} -is:retweet lang:en', #Va a traer los que tienen el hashtag '#machinelearning' y el -is:retweet es para que no traigra retweets
    'max_results':100  #Y que traiga 100 resultados maximo
}

# %%
import requests
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'id': '1453474432702468097', 'text': '#GRAMMYVault 🎵 Comedian Jonathan Winters and singer Peggy Lee (@peggyleemusic) conratulate GRAMMY winners @henrymancini and @jonimitchell.\n\n✨ March 11, 1970 at the 13th #GRAMMYs. https://t.co/R4JFKsSplR'}, {'id': '1453473084321767427', 'text': '#GRAMMYVault 🎵 Comedian Jonathan Winters and singer Peggy Lee (@peggyleemusic) conratulate GRAMMY winners @henrymancini and @jonimitchell.\n\n✨ March 11, 1970 at the 13th #GRAMMYs. https://t.co/72kdjdhB06'}, {'id': '1453472662244630529', 'text': 'Another album my dad @joshsmithguitar produced made it through the first round of the @RecordingAcad #GRAMMYs https://t.co/rfBvCmvTKa'}, {'id': '1453470742595649546', 'text': 'Ye will get artist of the year for DONDA and producing ‘Industry Baby’ #Grammys #Billboard #Ye #DONDA #IndustryBaby'}, {'id': '1453464644891418628', 'text': "🎶 As music’s only peer award, the participation of @RecordingAcad voting members is vital as together they illuminate and recognize musical excellence through the #GRAMMYs. ✨ Don't forget GRAMMY nominations will be revealed on November 23, 2021. #Vote4GRAMMYs"}, {'id': '1453463629781737472', 'text': 'Album of the year indeed 🦅🔥@RecordingAcad\n#BestReggaeAlbum #Vote4Grammys #recordingacademy #Grammys #FYC #ForYourConsideration #TopPrizeAlbum https://t.co/0Cc0MK5TCY'}, {'id': '1453463048023416841', 'text': "@Art2Live @KaceyMusgraves I'm voting for #starcrossed as #CountryAOY at the #Grammys.\u202f\u202f The folks who mis-categorized it can kiss my a**.  🤷"}, {'id': '1453462713020174344', 'text': 'For your Grammy consideration #GRAMMYs #grammyvoting #64thgrammys #standforchange @R2ACommittee @RepublicRecords https://t.co/ZmvEfTN9IW'}, {'id': '1453459914924249090', 'text': "Please read and share! Thanks so much, y'all! ❤️\n\n#grammys #foryourconsiderstion #americanamusic #singersongwriter\n\n@RecordingAcad @MTSManagement https://t.co/FqIz6WXIEf"}, {'id': '1453459292577845262', 'text': "We’re thrilled to announce that for the first time ever, an album of Yoko’s has been sent to the #GRAMMYs  for consideration. Click the link for all the details. And if you're a voter, vote for Yoko Miwa's Songs of Joy! #jazz #piano https://t.co/sEFuU61bae https://t.co/2l0P7DwxG8"}, {'id': '1453459057877164040', 'text': 'It is as honor to be considered, thank you all the support you’ve given Shall We Hope!\n#foryourgrammyconsideration voting members of the Recording Academy \n\nListen to Shall We Hope on all platforms: https://t.co/7qKl0G3SoQ\n\n#GRAMMYs  #RECORDINGACADEMY #FYC https://t.co/JoVRIRQiaa'}, {'id': '1453458484058599425', 'text': '“The discussions about possibly removing nominations review started long ago and the real work of putting together a subcommittee to get this right started about eight or nine months ago, so, this isn’t a direct ‘reaction’ to that situation.” #GRAMMYs https://t.co/3lbm28n4tp'}, {'id': '1453457610041028613', 'text': "Award season is coming up: #AMAs, #PCAs, #GRAMMYs... I'm actually excited to see @billieeilish back on the red carpet soon. 😏😅💕\n\n#BillieEilish #TheFemaleArtist #HappierThanEver #TheAlbum #aworldsalittleblurry #ThePopSpecial"}, {'id': '1453456348109176832', 'text': '#GRAMMYs submissions for next year. 😏💕🎶\n\n#BillieEilish #HappierThanEver #TheFemaleArtist #TheAlbum #aworldsalittleblurry #ThePopSpecial #PCAs https://t.co/q2W3dCyKlQ'}, {'id': '1453453318521561089', 'text': '216 entries for Gospel Song category for #Grammys 2022'}, {'id': '1453451461241753611', 'text': '@Variety @RollingStone @RecordingAcad #GRAMMYs #PermissionToDanceOnStageLA @SoFiStadium @BTS_twt\n\n#BTS always goes above and far far beyond.\n\n👀 🤭 😏 https://t.co/CsW7FUrXuH'}, {'id': '1453449355604549635', 'text': 'Critics and fans alike love the Critically Acclaimed #AssassinsCreedValhalla (Original Game Soundtrack) feat. score by @JesperKyd &amp; @SarahSchachner &amp; feat. @EinarSelvik1! Listen now worldwide!\n\n@assassinscreed @ubisoft @ubisoftmusic #gamemusic #gameaud ...

# %%
import pandas as pd
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                      id                                               text
# 0   1453474432702468097  #GRAMMYVault 🎵 Comedian Jonathan Winters and s...
# 1   1453473084321767427  #GRAMMYVault 🎵 Comedian Jonathan Winters and s...
# 2   1453472662244630529  Another album my dad @joshsmithguitar produced...
# 3   1453470742595649546  Ye will get artist of the year for DONDA and p...
# 4   1453464644891418628  🎶 As music’s only peer award, the participatio...
# ..                  ...                                                ...
# 95  1453346769719472132  Congratulations to a queen @faithevans this po...
# 96  1453346042619985922  @FinallyClean_ evermore for AOTY #GRAMMYs #ARI...
# 97  1453345574766346252   kacey musgraves #GRAMMYs https://t.co/DVXCn8gGJw
# 98  1453344667152617472  Charles Gounod: La reine de Saba may be stream...
# 99  1453344665600671750  Charles Gounod: La reine de Saba captures the ...
#
# [100 rows x 2 columns]

# %%
from nltk.tokenize import TweetTokenizer # libreria especifica para los tokenizar tweets 

tt = TweetTokenizer() # intanciamos ya que es un modelo lo que vamos a llamar
# Aplicar Tokenizer a la columna
tokenized_text = df['text'].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df=df[['tokenized_text']]
df
# Out:
#                                        tokenized_text
# 0   [#GRAMMYVault, 🎵, Comedian, Jonathan, Winters,...
# 1   [#GRAMMYVault, 🎵, Comedian, Jonathan, Winters,...
# 2   [Another, album, my, dad, @joshsmithguitar, pr...
# 3   [Ye, will, get, artist, of, the, year, for, DO...
# 4   [🎶, As, music, ’, s, only, peer, award, ,, the...
# ..                                                ...
# 95  [Congratulations, to, a, queen, @faithevans, t...
# 96  [@FinallyClean_, evermore, for, AOTY, #GRAMMYs...
# 97  [kacey, musgraves, #GRAMMYs, https://t.co/DVXC...
# 98  [Charles, Gounod, :, La, reine, de, Saba, may,...
# 99  [Charles, Gounod, :, La, reine, de, Saba, capt...
#
# [100 rows x 1 columns]

# %%
import re
i=0
for text in df['tokenized_text']:
    #text=eval(str_text) # lo convertimos en lista para poder iterar por palabra
    #print("\nTEXTO A ANALIZAR ->",text)
    j=0
    for palabra in text:
        if(re.search('^#+',palabra)):
            palabra = re.sub(r'.', '', palabra, count = 1) # eliminamos el primer caracter que es "#"
            text[j]=palabra
            j=j+1
        elif(re.search('^@+',palabra)):
            palabra = re.sub(r'.', '', palabra, count = 1) # eliminamos el primer caracter que es "@"
            text[j]=palabra
            j=j+1
        elif(re.search('^http+',palabra)):
            text.remove(palabra)  #ACA NO SUMAMOS J PORQUE QUITAMOS UN ELEMENTO DE LA LISTA
        else:
            text[j]=palabra
            j=j+1
        
    #print("\n TEXTO DEVULETO ->", text) 

    df['tokenized_text'][i] = text
    i=i+1

#df.to_csv('limpieza')
df
# Out:
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                        tokenized_text
# 0   [GRAMMYVault, 🎵, Comedian, Jonathan, Winters, ...
# 1   [GRAMMYVault, 🎵, Comedian, Jonathan, Winters, ...
# 2   [Another, album, my, dad, joshsmithguitar, pro...
# 3   [Ye, will, get, artist, of, the, year, for, DO...
# 4   [🎶, As, music, ’, s, only, peer, award, ,, the...
# ..                                                ...
# 95  [Congratulations, to, a, queen, faithevans, th...
# 96  [FinallyClean_, evermore, for, AOTY, GRAMMYs, ...
# 97                        [kacey, musgraves, GRAMMYs]
# 98  [Charles, Gounod, :, La, reine, de, Saba, may,...
# 99  [Charles, Gounod, :, La, reine, de, Saba, capt...
#
# [100 rows x 1 columns]

# %%
import nltk
#nltk.download('averaged_perceptron_tagger')
#nltk.download('tagsets')
df['pos_tokenized_text']=df['tokenized_text']

i=0
for text in df['tokenized_text']:    
    df['pos_tokenized_text'][i] = nltk.pos_tag(text)
    i=i+1
df
# Out:
# <ipython-input-68-18d6f18d1f13>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pos_tokenized_text']=df['tokenized_text']
# /media/eduardo/Anaconda/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                        tokenized_text  \
# 0   [GRAMMYVault, 🎵, Comedian, Jonathan, Winters, ...
# 1   [GRAMMYVault, 🎵, Comedian, Jonathan, Winters, ...
# 2   [Another, album, my, dad, joshsmithguitar, pro...
# 3   [Ye, will, get, artist, of, the, year, for, DO...
# 4   [🎶, As, music, ’, s, only, peer, award, ,, the...
# ..                                                ...
# 95  [Congratulations, to, a, queen, faithevans, th...
# 96  [FinallyClean_, evermore, for, AOTY, GRAMMYs, ...
# 97                        [kacey, musgraves, GRAMMYs]
# 98  [Charles, Gounod, :, La, reine, de, Saba, may,...
# 99  [Charles, Gounod, :, La, reine, de, Saba, capt...
#
#                                    pos_tokenized_text
# 0   [(GRAMMYVault, NNP), (🎵, NNP), (Comedian, NNP)...
# 1   [(GRAMMYVault, NNP), (🎵, NNP), (Comedian, NNP)...
# 2   [(Another, DT), (album, NN), (my, PRP$), (dad,...
# 3   [(Ye, NNP), (will, MD), (get, VB), (artist, NN...
# 4   [(🎶, NN), (As, IN), (music, NN), (’, NN), (s, ...
# ..                                                ...
# 95  [(Congratulations, NNS), (to, TO), (a, DT), (q...
# 96  [(FinallyClean_, NNP), (evermore, NN), (for, I...
# 97    [(kacey, NN), (musgraves, NNS), (GRAMMYs, NNP)]
# 98  [(Charles, NNP), (Gounod, NNP), (:, :), (La, N...
# 99  [(Charles, NNP), (Gounod, NNP), (:, :), (La, N...
#
# [100 rows x 2 columns]

# %% [markdown]
# # Obtener la lista y frecuencia de los sustantivos en singular y plural# NN-> sustantivo NNS -> sustantivo en plural

# %%
df=df[['pos_tokenized_text']]
df
# Out:
#                                    pos_tokenized_text
# 0   [(GRAMMYVault, NNP), (🎵, NNP), (Comedian, NNP)...
# 1   [(GRAMMYVault, NNP), (🎵, NNP), (Comedian, NNP)...
# 2   [(Another, DT), (album, NN), (my, PRP$), (dad,...
# 3   [(Ye, NNP), (will, MD), (get, VB), (artist, NN...
# 4   [(🎶, NN), (As, IN), (music, NN), (’, NN), (s, ...
# ..                                                ...
# 95  [(Congratulations, NNS), (to, TO), (a, DT), (q...
# 96  [(FinallyClean_, NNP), (evermore, NN), (for, I...
# 97    [(kacey, NN), (musgraves, NNS), (GRAMMYs, NNP)]
# 98  [(Charles, NNP), (Gounod, NNP), (:, :), (La, N...
# 99  [(Charles, NNP), (Gounod, NNP), (:, :), (La, N...
#
# [100 rows x 1 columns]

# %%
df['pos_tokenized_text'][0][0][1]
# Out:
# 'NNP'

# %%
from nltk.probability import FreqDist

tokenized_list = df.explode('pos_tokenized_text')
# Obtener frecuencia de cada término
i=0
for text in df['pos_tokenized_text']:
    j=0
    for tupla in text:
        if (tupla[1]=='NN' or tupla[1]=='NNS'):
            print("->",tupla[0])
        j=j+1
    i=i+1

#df['tok_text_no_stwrs'][0]

fdist = FreqDist(tokenized_list['pos_tokenized_text'])

# Convertir a dataframe
#df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
#df_fdist.columns = ['Frequency']
#df_fdist.index.name = 'Term'
#df_fdist.sort_values(by=['Frequency'], inplace=True)
#df_fdist
# Out:
# -> ('singer', 'NN')
# -> ('conratulate', 'NN')
# -> ('winners', 'NNS')
# -> ('singer', 'NN')
# -> ('conratulate', 'NN')
# -> ('winners', 'NNS')
# -> ('album', 'NN')
# -> ('dad', 'NN')
# -> ('joshsmithguitar', 'NN')
# -> ('round', 'NN')
# -> ('artist', 'NN')
# -> ('year', 'NN')
# -> ('🎶', 'NN')
# -> ('music', 'NN')
# -> ('’', 'NN')
# -> ('award', 'NN')
# -> ('participation', 'NN')
# -> ('members', 'NNS')
# -> ('excellence', 'NN')
# -> ('nominations', 'NNS')
# -> ('Album', 'NN')
# -> ('year', 'NN')
# -> ('recordingacademy', 'NN')
# -> ('voting', 'NN')
# -> ('folks', 'NNS')
# -> ('*', 'NN')
# -> ('🤷', 'NN')
# -> ('consideration', 'NN')
# -> ('standforchange', 'NN')
# -> ('read', 'NN')
# -> ('share', 'NN')
# -> ('Thanks', 'NNS')
# -> ("y'all", 'NN')
# -> ('grammys', 'NN')
# -> ('foryourconsiderstion', 'NN')
# -> ('singersongwriter', 'NN')
# -> ('time', 'NN')
# -> ('album', 'NN')
# -> ('s', 'NN')
# -> ('consideration', 'NN')
# -> ('link', 'NN')
# -> ('details', 'NNS')
# -> ('voter', 'NN')
# -> ('vote', 'NN')
# -> ('jazz', 'NN')
# -> ('piano', 'NN')
# -> ('https://t.co/2l0P7DwxG8', 'NN')
# -> ('support', 'NN')
# -> ('foryourgrammyconsideration', 'NN')
# -> ('members', 'NNS')
# -> ('platforms', 'NNS')
# -> ('#FYC', 'NN')
# -> ('discussions', 'NNS')
# -> ('nominations', 'NNS')
# -> ('review', 'NN')
# -> ('work', 'NN')
# -> ('subcommittee', 'NN')
# -> ('right', 'NN')
# -> ('months', 'NNS')
# -> ('isn', 'NN')
# -> ('‘', 'NN')
# -> ('reaction', 'NN')
# -> ('’', 'NN')
# -> ('situation', 'NN')
# -> ('season', 'NN')
# -> ('carpet', 'NN')
# -> ('submissions', 'NNS')
# -> ('year', 'NN')
# -> ('entries', 'NNS')
# -> ('category', 'NN')
# -> ('🤭', 'NN')
# -> ('😏', 'NN')
# -> ('Critics', 'NNS')
# -> ('fans', 'NNS')
# -> ('feat', 'NN')
# -> ('score', 'NN')
# -> ('feat', 'NN')
# -> ('assassinscreed', 'NN')
# -> ('gameaudio', 'NN')
# -> ('fyc', 'NN')
# -> ('grammys', 'NN')
# -> ('\u2060', 'NN')
# -> ('han', 'NN')
# -> ('revelado', 'NN')
# -> ('más', 'NN')
# -> ('categorías', 'NN')
# -> ('donde', 'NN')
# -> ('esta', 'NN')
# -> ('para', 'NN')
# -> ('los', 'NN')
# -> ('•', 'NN')
# -> ('Album', 'NN')
# -> ('Record', 'NN')
# -> ('Year', 'NN')
# -> ('Song', 'NN')
# -> ('Year', 'NN')
# -> ('moment', 'NN')
# -> ('😭', 'NN')
# -> ('contenders', 'NNS')
# -> ('work', 'NN')
# -> ('song', 'NN')
# -> ('“', 'NN')
# -> ('"', 'NNS')
# -> ('page', 'NN')
# -> ('song', 'NN')
# -> ('“', 'NN')
# -> ('wait', 'NN')
# -> ('“', 'NN')
# -> ('arrangement', 'NN')
# -> ('instruments', 'NNS')
# -> ('vocals', 'NNS')
# -> ('grammys', 'NN')
# -> ('trophies', 'NNS')
# -> ('record', 'NN')
# -> ('player', 'NN')
# -> ('grammyvoter', 'NN')
# -> ('power', 'NN')
# -> ('privilege', 'NN')
# -> ('prestige', 'NN')
# -> ('music', 'NN')
# -> ('s', 'NN')
# -> ('creators', 'NNS')
# -> ('hands', 'NNS')
# -> ('members', 'NNS')
# -> ('voting', 'NN')
# -> ('member', 'NN')
# -> ("don't", 'NN')
# -> ('forget', 'NN')
# -> ('generation', 'NN')
# -> ('shift', 'NN')
# -> ('music', 'NN')
# -> ('years', 'NNS')
# -> ('genuis', 'NN')
# -> ('debut', 'NN')
# -> ('record', 'NN')
# -> ('nothing', 'NN')
# -> ('moment', 'NN')
# -> ('losers', 'NNS')
# -> ('👑', 'NN')
# -> ('finneas', 'NNS')
# -> ('stories', 'NNS')
# -> ('celebrity', 'NN')
# -> ('magazine', 'NN')
# -> ('stars', 'NNS')
# -> ('event', 'NN')
# -> ('redcarpet', 'NN')
# -> ('fashion', 'NN')
# -> ('music', 'NN')
# -> ('actress', 'NN')
# -> ('actor', 'NN')
# -> ('movie', 'NN')
# -> ('camera', 'NN')
# -> ('film', 'NN')
# -> ('TSWorId', 'NN')
# -> ('Awards', 'NNS')
# -> ('variety', 'NN')
# -> ('#Emmys', 'NN')
# -> ('shakira', 'NN')
# -> ('musician', 'NN')
# -> ('"', 'NN')
# -> ('”', 'NN')
# -> ('video', 'NN')
# -> ('“', 'NN')
# -> ('consideration', 'NN')
# -> ('bestmusicalfilm', 'NN')
# -> ('gut', 'NN')
# -> ('feeling', 'NN')
# -> ('categories', 'NNS')
# -> ('Years', 'NNS')
# -> ('taylorswift13', 'NN')
# -> ('studio', 'NN')
# -> ('album', 'NN')
# -> ('“', 'NN')
# -> ('”', 'NN')
# -> ('award', 'NN')
# -> ('units', 'NNS')
# -> ('pop', 'NN')
# -> ('album', 'NN')
# -> ('history', 'NN')
# -> ('billboard', 'NN')
# -> ('goal', 'NN')
# -> ('change', 'NN')
# -> ('voters', 'NNS')
# -> ('area', 'NN')
# -> ('expertise', 'NN')
# -> ('Members', 'NNS')
# -> ('”', 'NN')
# -> ('album', 'NN')
# -> ('record', 'NN')
# -> ('song', 'NN')
# -> ('year', 'NN')
# -> ('artist', 'NN')
# -> ('GRAMMYs', 'NN')
# -> ('🎵', 'NN')
# -> ('outpouring', 'NN')
# -> ('creativity', 'NN')
# -> ('music', 'NN')
# -> ('community', 'NN')
# -> ('year', 'NN')
# -> ('voting', 'NN')
# -> ('member', 'NN')
# -> ('t', 'NN')
# -> ('forget', 'NN')
# -> ('vote', 'NN')
# -> ('🗳', 'NN')
# -> ('…', 'NN')
# -> ('round', 'NN')
# -> ('year', 'NN')
# -> ('trailblazers', 'NNS')
# -> ('Year', 'NN')
# -> ('bestRockperformance', 'NN')
# -> ('produceroftheyear', 'NN')
# -> ('jpusbrasil', 'NN')
# -> ('ricky_martin', 'NN')
# -> ('🎵', 'NN')
# -> ('outpouring', 'NN')
# -> ('creativity', 'NN')
# -> ('music', 'NN')
# -> ('community', 'NN')
# -> ('year', 'NN')
# -> ('voting', 'NN')
# -> ('member', 'NN')
# -> ('t', 'NN')
# -> ('forget', 'NN')
# -> ('vote', 'NN')
# -> ('🗳', 'NN')
# -> ('thethespianfly', 'NN')
# -> ('portraitphotography', 'NN')
# -> ('musicphotography', 'NN')
# -> ('thorstenroth212', 'NN')
# -> ('grammys', 'NN')
# -> ('"', 'NN')
# -> ('category', 'NN')
# -> ('voting', 'NN')
# -> ('consideration', 'NN')
# -> ('beats', 'NNS')
# -> ('rhymes', 'NNS')
# -> ('vote', 'NN')
# -> ('voter', 'NN')
# -> ('round', 'NN')
# -> ('voting', 'NN')
# -> ('vote', 'NN')
# -> ('difference', 'NN')
# -> ('GRAMMYs', 'NN')
# -> ('Lets', 'NNS')
# -> ('🤗', 'NN')
# -> ('💜', 'NN')
# -> ('friends', 'NNS')
# -> ('volumes', 'NNS')
# -> ('avierec', 'NNS')
# -> ('categories', 'NNS')
# -> ('label', 'NN')
# -> ('ballot', 'NN')
# -> ('consideration', 'NN')
# -> ('…', 'NN')
# -> ('brandicarlile', 'NN')
# -> ('artist', 'NN')
# -> ('aim', 'NN')
# -> ('misclassification', 'NN')
# -> ('music', 'NN')
# -> ('stand', 'NN')
# -> ('anything', 'NN')
# -> ('career', 'NN')
# -> ('dope', 'NN')
# -> ('grammy', 'NN')
# -> ('prayer', 'NN')
# -> ('circle', 'NN')
# -> ('award', 'NN')
# -> ('🕯', 'NN')
# -> ('🕯', 'NN')
# -> ('albums', 'NNS')
# -> ('"', 'NN')
# -> ('"', 'NN')
# -> ('🤞', 'NN')
# -> ('👀', 'NN')
# -> ('txt', 'NN')
# -> ('grammy', 'NN')
# -> ('grammy2022', 'NN')
# -> ('grammys', 'NN')
# -> ('grammys2022', 'NN')
# -> ('star', 'NN')
# -> ('co-star', 'NN')
# -> ('friend', 'NN')
# -> ('s', 'NN')
# -> ('wedding', 'NN')
# -> ('episodes', 'NNS')
# -> ('announce', 'NN')
# -> ('production', 'NN')
# -> ('team', 'NN')
# -> ('survivorcbs', 'NN')
# -> ('merge', 'NN')
# -> ('https://t.co/S7FTo0pOqf', 'NN')
# -> ('something', 'NN')
# -> ('click', 'NN')
# -> ('music', 'NN')
# -> ('velocity', 'NN')
# -> ('music', 'NN')
# -> ('singer', 'NN')
# -> ('supergroups', 'NNS')
# -> ('videogames', 'NNS')
# -> ('minutes', 'NNS')
# -> ('taylorswift13', 'NN')
# -> ('album', 'NN')
# -> ('’', 'NN')
# -> ('consideration', 'NN')
# -> ('”', 'NN')
# -> ('member', 'NN')
# -> ('vote', 'NN')
# -> ('#Vote4GRAMMYs', 'NN')
# -> ('journey', 'NN')
# -> ('space', 'NN')
# -> ('time', 'NN')
# -> ('documentary', 'NN')
# -> ('consideration', 'NN')
# -> ('album', 'NN')
# -> ('music', 'NN')
# -> ('vocals', 'NNS')
# -> ('#vocals', 'NNS')
# -> ('result', 'NN')
# -> ('category', 'NN')
# -> ('pick', 'NN')
# -> ('🏆', 'NN')
# -> ('years', 'NNS')
# -> ('pop', 'NN')
# -> ('album', 'NN')
# -> ('history', 'NN')
# -> ('time', 'NN')
# -> ('winner', 'NN')
# -> ('TaylorSwift', 'NN')
# -> ('✍', 'NN')
# -> ('band', 'NN')
# -> ('megahit', 'NN')
# -> ('birthdayboy', 'NN')
# -> ('mixset', 'NN')
# -> ('➕', 'NN')
# -> ('classics', 'NNS')
# -> ('s', 'NN')
# -> ('submissions', 'NNS')
# -> ('Album', 'NN')
# -> ('Record', 'NN')
# -> ('Performance', 'NN')
# -> ('Wizkid', 'NN')
# -> ('nomination', 'NN')
# -> ('celebrity', 'NN')
# -> ('naijagist', 'NN')
# -> ('#naijagist', 'NN')
# -> ('grammy', 'NN')
# -> ('consideration', 'NN')
# -> ('artist', 'NN')
# -> ('boundaries', 'NNS')
# -> ('representation', 'NN')
# -> ('inclusion', 'NN')
# -> ('pop', 'NN')
# -> ('music', 'NN')
# -> ('album', 'NN')
# -> ('+', 'NN')
# -> ('artists', 'NNS')
# -> ('music', 'NN')
# -> ('videos', 'NN')
# -> ('Consideration', 'NN')
# -> ('‘', 'NN')
# -> ('PEOPLE', 'NNS')
# -> ('melissablive', 'NN')
# -> ('https://t.co/dOgscc3EWN', 'NN')
# -> ('Consideration', 'NN')
# -> ('‘', 'NN')
# -> ('PEOPLE', 'NNS')
# -> ('melissablive', 'NN')
# -> ('https://t.co/BJYZkxJTcc', 'NN')
# -> ('daughter', 'NN')
# -> ('photo', 'NN')
# -> ('issue', 'NN')
# -> ('cover', 'NN')
# -> ('time', 'NN')
# -> ('girl', 'NN')
# -> ('s', 'NN')
# -> ('everyone', 'NN')
# -> ('monastir', 'NN')
# -> ('consideration', 'NN')
# -> ('midnightshelter', 'NN')
# -> ('cc', 'NN')
# -> ('sachalsings', 'NNS')
# -> ('foryourconsideration', 'NN')
# -> ('fyc', 'NN')
# -> ('grammys', 'NN')
# -> ('besttradicionalpopvocalalbum', 'NN')
# -> ('round', 'NN')
# -> ('voting', 'NN')
# -> ('..', 'NN')
# -> ('consideration', 'NN')
# -> ('ft', 'NN')
# -> ('Country', 'NN')
# -> ('Country', 'NN')
# -> ('grammys', 'NN')
# -> ('music', 'NN')
# -> ('field', 'NN')
# -> ('day', 'NN')
# -> ('downfall', 'NN')
# -> ('wednesdaythought', 'NN')
# -> ('Consideration', 'NN')
# -> ('grammys', 'NN')
# -> ('foryourconsideration', 'NN')
# -> ('ehnesquartet', 'NN')
# -> ('chrispierce', 'NN')
# -> ('album', 'NN')
# -> ('s', 'NN')
# -> ('Congratulations', 'NNS')
# -> ('bits', 'NNS')
# -> ('indieartist', 'NN')
# -> ('indiemusic', 'NN')
# -> ('theestallion', 'NN')
# -> ('iTunes', 'NNS')
# -> ('chartdata', 'NNS')
# -> ('beyonce', 'NN')
# -> ('quote', 'NN')
# -> ('edmsingers', 'NNS')
# -> ('willow', 'NN')
# -> ('female', 'NN')
# -> ('Singles', 'NNS')
# -> ('kymanimarley', 'NN')
# -> ('bobmarley', 'NN')
# -> ('🇲', 'NN')
# -> ('👓', 'NN')
# -> ('"', 'NN')
# -> ('"', 'NN')
# -> ('pop', 'NN')
# -> ('album', 'NN')
# -> ('era', 'NN')
# -> ('awards', 'NNS')
# -> ('awards', 'NNS')
# -> ('awards', 'NNS')
# -> ('awards', 'NNS')
# -> ('awards', 'NNS')
# -> ('Year', 'NN')
# -> ('scammys', 'NNS')
# -> ('GRAMMYs', 'NN')
# -> ('everything', 'NN')
# -> ('world', 'NN')
# -> ('love', 'NN')
# -> ('health', 'NN')
# -> ('everything', 'NN')
# -> ('boys', 'NNS')
# -> ('bottom', 'NN')
# -> ('heart', 'NN')
# -> ('brightlightx2', 'NN')
# -> ('GRAMMYs', 'NN')
# -> ('fun', 'NN')
# -> ('friends', 'NNS')
# -> ('song', 'NN')
# -> ('part', 'NN')
# -> ('album', 'NN')
# -> ('contributions', 'NNS')
# -> ('refugees', 'NNS')
# -> ('immigrants', 'NNS')
# -> ('Year', 'NN')
# -> ('Record', 'NN')
# -> ('Year', 'NN')
# -> ('https://t.co/wqm2NKiUAg', 'NN')
# -> ('CONSIDERATION', 'NN')
# -> ('categories', 'NNS')
# -> ('artist', 'NN')
# -> ('manager', 'NN')
# -> ('publisher', 'NN')
# -> ('album', 'NN')
# -> ('year', 'NN')
# -> ('Voters', 'NNS')
# -> ('consideration', 'NN')
# -> ('GRAMMYs', 'NN')
# -> ('wizkidayo', 'NN')
# -> ('afrobeats', 'NNS')
# -> ('music', 'NN')
# -> ('wizkidofficials', 'NNS')
# -> ('https://t.co/ecj1eTaWvJ', 'NN')
# -> ('stage', 'NN')
# -> ('gala', 'NN')
# -> ('part', 'NN')
# -> ('ticket', 'NN')
# -> ('registration', 'NN')
# -> ('https://t.co/deBN3jhIaU', 'NN')
# -> ('banner', 'NN')
# -> ('"', 'NN')
# -> ('category', 'NN')
# -> ('chartscyruus', 'NN')
# -> ('thekidlaroi', 'NN')
# -> ('billboard', 'NN')
# -> ('thekidlaroi', 'NN')
# -> ('”', 'NN')
# -> ('“', 'NN')
# -> ('billboard', 'NN')
# -> ('reports', 'NNS')
# -> ('thebeatles', 'NNS')
# -> ('coldplay', 'NN')
# -> ('justsayin', 'NN')
# -> ('reports', 'NNS')
# -> ('cuts', 'NNS')
# -> ('royalties', 'NNS')
# -> ('category', 'NN')
# -> ('controversy', 'NN')
# -> ('music', 'NN')
# -> ('musicbusiness', 'NN')
# -> ('musicnews', 'NNS')
# -> ('#Grammys', 'NN')
# -> ("haven't", 'NN')
# -> ('music', 'NN')
# -> ('fashion', 'NN')
# -> ('beauty', 'NN')
# -> ('series', 'NN')
# -> ('tiktok', 'NN')
# -> ('tiktoker', 'NN')
# -> ('trump', 'NN')
# -> ('ellenshow', 'NN')
# -> ('https://t.co/YKwLXe8y3i', 'NN')
# -> ('entries', 'NNS')
# -> ('nomination', 'NN')
# -> ('category', 'NN')
# -> ('record', 'NN')
# -> ('year', 'NN')
# -> ('roots', 'NNS')
# -> ('music', 'NN')
# -> ('album', 'NN')
# -> ('reports', 'NNS')
# -> ('cuts', 'NNS')
# -> ('royalties', 'NNS')
# -> ('category', 'NN')
# -> ('controversy', 'NN')
# -> ('music', 'NN')
# -> ('musicbusiness', 'NN')
# -> ('musicnews', 'NNS')
# -> ('#Grammys', 'NN')
# -> ('Congratulations', 'NNS')
# -> ('faithevans', 'NNS')
# -> ('today', 'NN')
# -> ('everyday', 'NN')
# -> ('win', 'NN')
# -> ('evermore', 'NN')
# -> ('kacey', 'NN')
# -> ('musgraves', 'NNS')
# -> ('fyc', 'NN')
# -> ('#newmusic', 'NN')
# -> ('performance', 'NN')
# -> ('masterpiece', 'NN')
# -> ('struggle', 'NN')
# -> ('love', 'NN')
# -> ('obligation', 'NN')
# -> ('intrigue', 'NN')
# -> ('jealousy', 'NN')
# -> ('betrayal', 'NN')
# -> ('fyc', 'NN')

# %%
df=df[['pos_tokenized_text']]
df
# Out:
#                                    pos_tokenized_text
# 0   [(🎶, NN), (As, IN), (music, NN), (’, NN), (s, ...
# 1   [(Album, NN), (of, IN), (the, DT), (year, NN),...
# 2   [(@Art2Live, JJ), (@KaceyMusgraves, NNS), (I'm...
# 3   [(For, IN), (your, PRP$), (Grammy, NNP), (cons...
# 4   [(Please, NNP), (read, NN), (and, CC), (share,...
# ..                                                ...
# 95  [(Charles, NNP), (Gounod, NNP), (:, :), (La, N...
# 96  [(The, DT), (first, JJ), (round, NN), (of, IN)...
# 97  [(Wizkid, NNP), (shoulda, NN), (submitted, VBD...
# 98  [(taylor, NN), (swift, NN), (#GRAMMYs, NNP), (...
# 99  [(These, DT), (releases, NNS), (and, CC), (mor...
#
# [100 rows x 1 columns]
